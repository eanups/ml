# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '/Users/anup.sethuram/DEV/LM/EanS/ml30/ml30/ml-ng/utils')
from logistic import draw_vthresh, plot_data

# %%
class LogisticRegression:


    def sigmoid(z):
        """
        z : wx + b 
        return the sigmoid value for z
        """
        return 1 / (1 + np.exp(-z))

# %%
# Plot Sigmoid function. 

z_tmp = np.arange(-10, 11)
y = sigmoid(z_tmp)

np.set_printoptions(precision=3)
print("IN z , OUT sigmoid(z)")
print(np.c_[z_tmp, y])
# Out:
# IN z , OUT sigmoid(z)
# [[-1.000e+01  4.540e-05]
#  [-9.000e+00  1.234e-04]
#  [-8.000e+00  3.354e-04]
#  [-7.000e+00  9.111e-04]
#  [-6.000e+00  2.473e-03]
#  [-5.000e+00  6.693e-03]
#  [-4.000e+00  1.799e-02]
#  [-3.000e+00  4.743e-02]
#  [-2.000e+00  1.192e-01]
#  [-1.000e+00  2.689e-01]
#  [ 0.000e+00  5.000e-01]
#  [ 1.000e+00  7.311e-01]
#  [ 2.000e+00  8.808e-01]
#  [ 3.000e+00  9.526e-01]
#  [ 4.000e+00  9.820e-01]
#  [ 5.000e+00  9.933e-01]
#  [ 6.000e+00  9.975e-01]
#  [ 7.000e+00  9.991e-01]
#  [ 8.000e+00  9.997e-01]
#  [ 9.000e+00  9.999e-01]
#  [ 1.000e+01  1.000e+00]]

# %%
# Plot z vs sigmoid(z)

fig,ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(z_tmp, y, c="b")

ax.set_title("Sigmoid function")
ax.set_ylabel('sigmoid(z)')
ax.set_xlabel('z')
draw_vthresh(ax,0)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Logistic regression model applies the sigmoid to the familiar linear regression model as shown below:
#
# $$ f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = g(\mathbf{w} \cdot \mathbf{x}^{(i)} + b ) $$
#
#   where,  $ z = wx + b ;\space g(z) = \frac{1}{1+e^{-z}}$

# %%
# Sample data for Logistic Regression

X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])  #(m,n)
y_train = np.array([0, 0, 0, 1, 1, 1])

# %%
X_train, y_train
# Out:
# (array([[0.5, 1.5],
#         [1. , 1. ],
#         [1.5, 0.5],
#         [3. , 0.5],
#         [2. , 2. ],
#         [1. , 2.5]]),
#  array([0, 0, 0, 1, 1, 1]))

# %%
# Plot points

fig,ax = plt.subplots(1,1,figsize=(4,4))
plot_data(X_train, y_train, ax)

ax.axis([0, 4, 0, 3.5])
ax.set_ylabel('$x_1$', fontsize=12)
ax.set_xlabel('$x_0$', fontsize=12)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
X_train.shape
# Out:
# (6, 2)

# %%
def compute_cost(X, y, w, b):
    m = X.shape[0]
    cost = 0.0
    for i in range(m):
        z_i = np.dot(w, X[i]) + b
        f_wb_i = sigmoid(z_i)
        loss = - y[i] * np.log(f_wb_i) - (1 - y[i]) * np.log (1 - f_wb_i)
        cost += loss 

    return cost/m
